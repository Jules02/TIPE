# %%
import matplotlib.pyplot as plt

import numpy as np

from skimage import io, color, transform
from skimage.feature import hog

import joblib

# %%
test_image = io.imread('img/testset/chir/mask-chir2.jpg')  
test_image = color.rgb2gray(test_image)
test_image = transform.rescale(test_image, 0.5)
test_image = test_image[:160, 40:180]

plt.imshow(test_image, cmap='gray')
plt.axis('off');

# %%
positive_patches_shape = (62, 47)

# %%
def sliding_window(img, patch_size=positive_patches_shape,
                   istep=2, jstep=2, scale=1.0):
    Ni, Nj = (int(scale * s) for s in patch_size)
    for i in range(0, img.shape[0] - Ni, istep):
        for j in range(0, img.shape[1] - Ni, jstep):
            patch = img[i:i + Ni, j:j + Nj]
            if scale != 1:
                patch = transform.resize(patch, patch_size)
            yield (i, j), patch
            
indices, patches = zip(*sliding_window(test_image))
patches_hog = np.array([hog(patch) for patch in patches])
patches_hog.shape
# Out:
# (270, 1215)

# %%
filename = 'temp_model.sav'
loaded_model = joblib.load(filename)
labels = loaded_model.predict(patches_hog)
labels.sum()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-1a5e7b69edfd> in <module>
#       1 filename = 'temp_model.sav'
# ----> 2 loaded_model = joblib.load(filename)
#       3 labels = loaded_model.predict(patches_hog)
#       4 labels.sum()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     575             obj = _unpickle(fobj)
#     576     else:
# --> 577         with open(filename, 'rb') as f:
#     578             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     579                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_model.sav'

# %%
fig, ax = plt.subplots()
ax.imshow(test_image, cmap='gray')
ax.axis('off')

Ni, Nj = positive_patches[0].shape
indices = np.array(indices)

for i, j in indices[labels == 1]:
    ax.add_patch(plt.Rectangle((j, i), Nj, Ni, edgecolor='red',
                               alpha=0.3, lw=2, facecolor='none'))
