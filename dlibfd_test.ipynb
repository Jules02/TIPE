# %% [markdown]
# # dlib HOG face detector

# %%
from matplotlib import pyplot as plt
import cv2
import dlib
import os.path

# dlib HOG face detector
detector = dlib.get_frontal_face_detector()
# dlib face landmark estimation
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# chargement de l'image
file = "img/testset/chir/mask-chir1.jpg"
if not(os.path.isfile(file)):
    raise Exception("Image not found")
image = cv2.imread(file)
#image = cv2.resize(image, (600, 500))
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# detect the faces
rects = detector(gray, 1)

print("Found {} face".format(len(rects)))

# go through the face bounding boxes
for rect in rects:
    ## Face rectangle
    # extract the coordinates of the bounding box
    x1 = rect.left()
    y1 = rect.top()
    x2 = rect.right()
    y2 = rect.bottom()

    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)

    ## Face landmarks
    # apply the shape predictor to the face ROI
    shape = predictor(gray, rect)

    for n in range(0, 68):
        x = shape.part(n).x
        y = shape.part(n).y
        cv2.circle(image, (x, y), 4, (255, 0, 0), -1)

plt.imshow(image)
plt.title("Image")
plt.show()
# Out:
# Found 1 face

# %%
pip install dlib
# Out:
# Requirement already satisfied: dlib in /Users/julesdupont/opt/anaconda3/lib/python3.8/site-packages (19.24.0)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
